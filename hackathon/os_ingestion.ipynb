# %%
# !pip install -q xlrd langchain_community langchain_core requests-aws4auth opensearch-py

# %%
import os 
import boto3
import re
import pandas as pd
import datetime
from io import BytesIO
from langchain_core.documents import Document
from langchain_aws import BedrockEmbeddings
from opensearchpy import OpenSearch, RequestsHttpConnection
import json 
from requests_aws4auth import AWS4Auth

# %%
FILE_CONFIGS = ['s3://canada-gen-ai/health_index_augdata.csv']
INDEX_CONFIGS ={'Hackathon_index': 'innovator_hack_index'}

# %%
# read csv file from S3 
def read_csv(file_path):
    s3 = boto3.client('s3')
    bucket, key = file_path.replace("s3://", "").split("/", 1)
    response = s3.get_object(Bucket=bucket, Key=key)
    file_content = response['Body'].read()
    df = pd.read_csv(BytesIO(file_content))

    return df, file_path


# create OpenSearch vector search index
def create_vector_search_index(opensearch_client, index_name, dimension):
    index_body = {
        "settings": {
            "index": {
                "number_of_shards": 1,
                "number_of_replicas": 1,
                "knn": True  # Enable k-NN search
            }
        },
        "mappings": {
            "properties": {
                "snapshot_date": {"type": "date", "format": "yyy-MM-dd HH:mm:ss"},
                "source": {"type": "keyword"},  # Source name
                "content": {"type": "text"},  # Store row content as text
                "embedding": {"type": "knn_vector", "dimension": dimension}  # Vector embedding for k-NN search
            }
        }
    }
    try:
        response = opensearch_client.indices.create(index=index_name, body=index_body)
        print(f"Index {index_name} created successfully.")
    except Exception as e:
        if 'resource_already_exists_exception' in str(e):
            print(f"Index {index_name} already exists. Skipping creation.")
        else:
            raise


# add documents to OpenSearch index
def add_documents_to_opensearch(opensearch_client, index_name, df, bedrock_embeddings):
    document_counter = 0
    for i, row in df.iterrows():
        try:
            row_content_serialized = {
                key: (value if pd.notna(value) else None)
                for key, value in row.items() if key not in ['file_path']
            }
            
            text = " ".join([str(value) for value in row.values if pd.notna(value)])
            
            embedding = bedrock_embeddings.embed_documents([text])[0]
            
            row_content_text = json.dumps(row_content_serialized)
            
            source_name = "health_index_augdata.csv"

            
            document = {
                'snapshot_date': datetime.datetime.utcnow().strftime('%Y-%m-%d %H:%M:%S'),
                'source': source_name,
                'content': row_content_text,
                'embedding': embedding
            }
            
            response = opensearch_client.index(index=index_name, body=document)
            print(f"Document {i} indexed successfully.")
            document_counter += 1
            
        except Exception as e:
            print(f"Failed to index document {i} due to inconsistent value: {e}")
            continue


# Main processing function
def process_csv_files(file_configs, opensearch_client, index_name, bedrock_embeddings, dimension):
    for file_path in file_configs:
        print(f"Processing file: {file_path}")
        df, _ = read_csv(file_path)
        create_vector_search_index(opensearch_client, index_name, dimension)
        add_documents_to_opensearch(opensearch_client, index_name, df, bedrock_embeddings)

# %%
# Initialize OpenSearch client
def init_opensearch_client(host, port, region, service):
    credentials = boto3.Session().get_credentials()
    awsauth = AWS4Auth(credentials.access_key, credentials.secret_key, region, service, session_token=credentials.token)
    return OpenSearch(
        hosts=[{'host': host, 'port': port}],
        http_auth=awsauth,
        use_ssl=True,
        verify_certs=True,
        connection_class=RequestsHttpConnection,
        timeout=3000
    )


opensearch_host = 'iellhhrn6kean028im78.us-east-1.aoss.amazonaws.com'
opensearch_port = 443
opensearch_region = 'us-east-1'
opensearch_service = 'aoss'
index_name = INDEX_CONFIGS['Hackathon_index']
dimension = 1024

opensearch_client = init_opensearch_client(opensearch_host, opensearch_port, opensearch_region, opensearch_service)
embedding_model = BedrockEmbeddings(client=boto3.client("bedrock-runtime", region_name=opensearch_region), model_id="amazon.titan-embed-text-v2:0")

# %%
process_csv_files(FILE_CONFIGS, opensearch_client, index_name, embedding_model, dimension)
# Out:
# Processing file: s3://canada-gen-ai/health_index_augdata.csv
# Index innovator_hack_index created successfully.
# Document 0 indexed successfully.
# Document 1 indexed successfully.
# Document 2 indexed successfully.
# Document 3 indexed successfully.
# Document 4 indexed successfully.
# Document 5 indexed successfully.
# Document 6 indexed successfully.
# Document 7 indexed successfully.
# Document 8 indexed successfully.
# Document 9 indexed successfully.
# Document 10 indexed successfully.
# Document 11 indexed successfully.
# Document 12 indexed successfully.
# Document 13 indexed successfully.
# Document 14 indexed successfully.
# Document 15 indexed successfully.
# Document 16 indexed successfully.
# Document 17 indexed successfully.
# Document 18 indexed successfully.
# Document 19 indexed successfully.
# Document 20 indexed successfully.
# Document 21 indexed successfully.
# Document 22 indexed successfully.
# Document 23 indexed successfully.
# Document 24 indexed successfully.
# Document 25 indexed successfully.
# Document 26 indexed successfully.
# Document 27 indexed successfully.
# Document 28 indexed successfully.
# Document 29 indexed successfully.
# Document 30 indexed successfully.
# Document 31 indexed successfully.
# Document 32 indexed successfully.
# Document 33 indexed successfully.
# Document 34 indexed successfully.
# Document 35 indexed successfully.
# Document 36 indexed successfully.
# Document 37 indexed successfully.
# Document 38 indexed successfully.
# Document 39 indexed successfully.
# Document 40 indexed successfully.
# Document 41 indexed successfully.
# Document 42 indexed successfully.
# Document 43 indexed successfully.
# Document 44 indexed successfully.
# Document 45 indexed successfully.
# Document 46 indexed successfully.
# Document 47 indexed successfully.
# Document 48 indexed successfully.
# Document 49 indexed successfully.
# Document 50 indexed successfully.
# Document 51 indexed successfully.
# Document 52 indexed successfully.
# Document 53 indexed successfully.
# Document 54 indexed successfully.
# Document 55 indexed successfully.
# Document 56 indexed successfully.
# Document 57 indexed successfully.
# Document 58 indexed successfully.
# Document 59 indexed successfully.
# Document 60 indexed successfully.
# Document 61 indexed successfully.
# Document 62 indexed successfully.
# Document 63 indexed successfully.
# Document 64 indexed successfully.
# Document 65 indexed successfully.
# Document 66 indexed successfully.
# Document 67 indexed successfully.
# Document 68 indexed successfully.
# Document 69 indexed successfully.
# Document 70 indexed successfully.
# Document 71 indexed successfully.
# Document 72 indexed successfully.
# Document 73 indexed successfully.
# Document 74 indexed successfully.
# Document 75 indexed successfully.
# Document 76 indexed successfully.
# Document 77 indexed successfully.
# Document 78 indexed successfully.
# Document 79 indexed successfully.
# Document 80 indexed successfully.
# Document 81 indexed successfully.
# Document 82 indexed successfully.
# Document 83 indexed successfully.
# Document 84 indexed successfully.
# Document 85 indexed successfully.
# Document 86 indexed successfully.
# Document 87 indexed successfully.
# Document 88 indexed successfully.
# Document 89 indexed successfully.
# Document 90 indexed successfully.
# Document 91 indexed successfully.
# Document 92 indexed successfully.
# Document 93 indexed successfully.
# Document 94 indexed successfully.
# Document 95 indexed successfully.
# Document 96 indexed successfully.
# Document 97 indexed successfully.
# Document 98 indexed successfully.
# Document 99 indexed successfully.
# Document 100 indexed successfully.
# Document 101 indexed successfully.
# Document 102 indexed successfully.
# Document 103 indexed successfully.
# Document 104 indexed successfully.
# Document 105 indexed successfully.
# Document 106 indexed successfully.
# Document 107 indexed successfully.
# Document 108 indexed successfully.
# Document 109 indexed successfully.
# Document 110 indexed successfully.
# Document 111 indexed successfully.
# Document 112 indexed successfully.
# Document 113 indexed successfully.
# Document 114 indexed successfully.
# Document 115 indexed successfully.
# Document 116 indexed successfully.
# Document 117 indexed successfully.
# Document 118 indexed successfully.
# Document 119 indexed successfully.
# Document 120 indexed successfully.
# Document 121 indexed successfully.
# Document 122 indexed successfully.
# Document 123 indexed successfully.
# Document 124 indexed successfully.
# Document 125 indexed successfully.
# Document 126 indexed successfully.
# Document 127 indexed successfully.
# Document 128 indexed successfully.
# Document 129 indexed successfully.
# Document 130 indexed successfully.
# Document 131 indexed successfully.
# Document 132 indexed successfully.
# Document 133 indexed successfully.
# Document 134 indexed successfully.
# Document 135 indexed successfully.
# Document 136 indexed successfully.
# Document 137 indexed successfully.
# Document 138 indexed successfully.
# Document 139 indexed successfully.
# Document 140 indexed successfully.
# Document 141 indexed successfully.
# Document 142 indexed successfully.
# Document 143 indexed successfully.
# Document 144 indexed successfully.
# Document 145 indexed successfully.
# Document 146 indexed successfully.
# Document 147 indexed successfully.
# Document 148 indexed successfully.
# Document 149 indexed successfully.
# Document 150 indexed successfully.
# Document 151 indexed successfully.
# Document 152 indexed successfully.
# Document 153 indexed successfully.
# Document 154 indexed successfully.
# Document 155 indexed successfully.
# Document 156 indexed successfully.
# Document 157 indexed successfully.
# Document 158 indexed successfully.
# Document 159 indexed successfully.
# Document 160 indexed successfully.
# Document 161 indexed successfully.
# Document 162 indexed successfully.
# Document 163 indexed successfully.
# Document 164 indexed successfully.
# Document 165 indexed successfully.
# Document 166 indexed successfully.
# Document 167 indexed successfully.
# Document 168 indexed successfully.
# Document 169 indexed successfully.
# Document 170 indexed successfully.
# Document 171 indexed successfully.
# Document 172 indexed successfully.
# Document 173 indexed successfully.
# Document 174 indexed successfully.
# Document 175 indexed successfully.
# Document 176 indexed successfully.
# Document 177 indexed successfully.
# Document 178 indexed successfully.
# Document 179 indexed successfully.
# Document 180 indexed successfully.
# Document 181 indexed successfully.
# Document 182 indexed successfully.
# Document 183 indexed successfully.
# Document 184 indexed successfully.
# Document 185 indexed successfully.
# Document 186 indexed successfully.
# Document 187 indexed successfully.
# Document 188 indexed successfully.
# Document 189 indexed successfully.
# Document 190 indexed successfully.
# Document 191 indexed successfully.
# Document 192 indexed successfully.
# Document 193 indexed successfully.
# Document 194 indexed successfully.
# Document 195 indexed successfully.
# Document 196 indexed successfully.
# Document 197 indexed successfully.
# Document 198 indexed successfully.
# Document 199 indexed successfully.
# Document 200 indexed successfully.
# Document 201 indexed successfully.
# Document 202 indexed successfully.
# Document 203 indexed successfully.
# Document 204 indexed successfully.
# Document 205 indexed successfully.
# Document 206 indexed successfully.
# Document 207 indexed successfully.
# Document 208 indexed successfully.
# Document 209 indexed successfully.
# Document 210 indexed successfully.
# Document 211 indexed successfully.
# Document 212 indexed successfully.
# Document 213 indexed successfully.
# Document 214 indexed successfully.
# Document 215 indexed successfully.
# Document 216 indexed successfully.
# Document 217 indexed successfully.
# Document 218 indexed successfully.
# Document 219 indexed successfully.
# Document 220 indexed successfully.
# Document 221 indexed successfully.
# Document 222 indexed successfully.
# Document 223 indexed successfully.
# Document 224 indexed successfully.
# Document 225 indexed successfully.
# Document 226 indexed successfully.
# Document 227 indexed successfully.
# Document 228 indexed successfully.
# Document 229 indexed successfully.
# Document 230 indexed successfully.
# Document 231 indexed successfully.
# Document 232 indexed successfully.
# Document 233 indexed successfully.
# Document 234 indexed successfully.
# Document 235 indexed successfully.
# Document 236 indexed successfully.
# Document 237 indexed successfully.
# Document 238 indexed successfully.
# Document 239 indexed successfully.
# Document 240 indexed successfully.
# Document 241 indexed successfully.
# Document 242 indexed successfully.
# Document 243 indexed successfully.
# Document 244 indexed successfully.
# Document 245 indexed successfully.
# Document 246 indexed successfully.
# Document 247 indexed successfully.
# Document 248 indexed successfully.
# Document 249 indexed successfully.
# Document 250 indexed successfully.
# Document 251 indexed successfully.
# Document 252 indexed successfully.
# Document 253 indexed successfully.
# Document 254 indexed successfully.
# Document 255 indexed successfully.
# Document 256 indexed successfully.
# Document 257 indexed successfully.
# Document 258 indexed successfully.
# Document 259 indexed successfully.
# Document 260 indexed successfully.
# Document 261 indexed successfully.
# Document 262 indexed successfully.
# Document 263 indexed successfully.
# Document 264 indexed successfully.
# Document 265 indexed successfully.
# Document 266 indexed successfully.
# Document 267 indexed successfully.
# Document 268 indexed successfully.
# Document 269 indexed successfully.
# Document 270 indexed successfully.
# Document 271 indexed successfully.
# Document 272 indexed successfully.
# Document 273 indexed successfully.
# Document 274 indexed successfully.
# Document 275 indexed successfully.
# Document 276 indexed successfully.
# Document 277 indexed successfully.
# Document 278 indexed successfully.
# Document 279 indexed successfully.
# Document 280 indexed successfully.
# Document 281 indexed successfully.
# Document 282 indexed successfully.
# Document 283 indexed successfully.
# Document 284 indexed successfully.
# Document 285 indexed successfully.
# Document 286 indexed successfully.
# Document 287 indexed successfully.
# Document 288 indexed successfully.
# Document 289 indexed successfully.
# Document 290 indexed successfully.
# Document 291 indexed successfully.
# Document 292 indexed successfully.
# Document 293 indexed successfully.
# Document 294 indexed successfully.
# Document 295 indexed successfully.
# Document 296 indexed successfully.
# Document 297 indexed successfully.
# Document 298 indexed successfully.
# Document 299 indexed successfully.
# Document 300 indexed successfully.
# Document 301 indexed successfully.
# Document 302 indexed successfully.
# Document 303 indexed successfully.
# Document 304 indexed successfully.
# Document 305 indexed successfully.
# Document 306 indexed successfully.
# Document 307 indexed successfully.
# Document 308 indexed successfully.
# Document 309 indexed successfully.
# Document 310 indexed successfully.
# Document 311 indexed successfully.
# Document 312 indexed successfully.
# Document 313 indexed successfully.
# Document 314 indexed successfully.
# Document 315 indexed successfully.
# Document 316 indexed successfully.
# Document 317 indexed successfully.
# Document 318 indexed successfully.
# Document 319 indexed successfully.
# Document 320 indexed successfully.
# Document 321 indexed successfully.
# Document 322 indexed successfully.
# Document 323 indexed successfully.
# Document 324 indexed successfully.
# Document 325 indexed successfully.
# Document 326 indexed successfully.
# Document 327 indexed successfully.
# Document 328 indexed successfully.
# Document 329 indexed successfully.
# Document 330 indexed successfully.
# Document 331 indexed successfully.
# Document 332 indexed successfully.
# Document 333 indexed successfully.
# Document 334 indexed successfully.
# Document 335 indexed successfully.
# Document 336 indexed successfully.
# Document 337 indexed successfully.
# Document 338 indexed successfully.
# Document 339 indexed successfully.
# Document 340 indexed successfully.
# Document 341 indexed successfully.
# Document 342 indexed successfully.
# Document 343 indexed successfully.
# Document 344 indexed successfully.
# Document 345 indexed successfully.
# Document 346 indexed successfully.
# Document 347 indexed successfully.
# Document 348 indexed successfully.
# Document 349 indexed successfully.
# Document 350 indexed successfully.
# Document 351 indexed successfully.
# Document 352 indexed successfully.
# Document 353 indexed successfully.
# Document 354 indexed successfully.
# Document 355 indexed successfully.
# Document 356 indexed successfully.
# Document 357 indexed successfully.
# Document 358 indexed successfully.
# Document 359 indexed successfully.
# Document 360 indexed successfully.
# Document 361 indexed successfully.
# Document 362 indexed successfully.
# Document 363 indexed successfully.
# Document 364 indexed successfully.
# Document 365 indexed successfully.
# Document 366 indexed successfully.
# Document 367 indexed successfully.
# Document 368 indexed successfully.
# Document 369 indexed successfully.
# Document 370 indexed successfully.
# Document 371 indexed successfully.
# Document 372 indexed successfully.
# Document 373 indexed successfully.
# Document 374 indexed successfully.
# Document 375 indexed successfully.
# Document 376 indexed successfully.
# Document 377 indexed successfully.
# Document 378 indexed successfully.
# Document 379 indexed successfully.
# Document 380 indexed successfully.
# Document 381 indexed successfully.
# Document 382 indexed successfully.
# Document 383 indexed successfully.
# Document 384 indexed successfully.
# Document 385 indexed successfully.
# Document 386 indexed successfully.
# Document 387 indexed successfully.
# Document 388 indexed successfully.
# Document 389 indexed successfully.
# Document 390 indexed successfully.
# Document 391 indexed successfully.
# Document 392 indexed successfully.
# Document 393 indexed successfully.
# Document 394 indexed successfully.
# Document 395 indexed successfully.
# Document 396 indexed successfully.
# Document 397 indexed successfully.
# Document 398 indexed successfully.
# Document 399 indexed successfully.
# Document 400 indexed successfully.
# Document 401 indexed successfully.
# Document 402 indexed successfully.
# Document 403 indexed successfully.
# Document 404 indexed successfully.
# Document 405 indexed successfully.
# Document 406 indexed successfully.
# Document 407 indexed successfully.
# Document 408 indexed successfully.
# Document 409 indexed successfully.
# Document 410 indexed successfully.
# Document 411 indexed successfully.
# Document 412 indexed successfully.
# Document 413 indexed successfully.
# Document 414 indexed successfully.
# Document 415 indexed successfully.
# Document 416 indexed successfully.
# Document 417 indexed successfully.
# Document 418 indexed successfully.
# Document 419 indexed successfully.
# Document 420 indexed successfully.
# Document 421 indexed successfully.
# Document 422 indexed successfully.
# Document 423 indexed successfully.
# Document 424 indexed successfully.
# Document 425 indexed successfully.
# Document 426 indexed successfully.
# Document 427 indexed successfully.
# Document 428 indexed successfully.
# Document 429 indexed successfully.
# Document 430 indexed successfully.
# Document 431 indexed successfully.
# Document 432 indexed successfully.
# Document 433 indexed successfully.
# Document 434 indexed successfully.
# Document 435 indexed successfully.
# Document 436 indexed successfully.
# Document 437 indexed successfully.
# Document 438 indexed successfully.
# Document 439 indexed successfully.
# Document 440 indexed successfully.
# Document 441 indexed successfully.
# Document 442 indexed successfully.
# Document 443 indexed successfully.
# Document 444 indexed successfully.
# Document 445 indexed successfully.
# Document 446 indexed successfully.
# Document 447 indexed successfully.
# Document 448 indexed successfully.
# Document 449 indexed successfully.
# Document 450 indexed successfully.
# Document 451 indexed successfully.
# Document 452 indexed successfully.
# Document 453 indexed successfully.
# Document 454 indexed successfully.
# Document 455 indexed successfully.
# Document 456 indexed successfully.
# Document 457 indexed successfully.
# Document 458 indexed successfully.
# Document 459 indexed successfully.
# Document 460 indexed successfully.
# Document 461 indexed successfully.
# Document 462 indexed successfully.
# Document 463 indexed successfully.
# Document 464 indexed successfully.
# Document 465 indexed successfully.
# Document 466 indexed successfully.
# Document 467 indexed successfully.
# Document 468 indexed successfully.
# Document 469 indexed successfully.
